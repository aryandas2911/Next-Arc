# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load dataset

# %%
df=pd.read_csv("../data/raw/anime.csv")

# %%
df.head(1)
# Out:
#    anime_id          Name  English name Other name Score  \
# 0         1  Cowboy Bebop  Cowboy Bebop  カウボーイビバップ  8.75
#
#                           Genres  \
# 0  Action, Award Winning, Sci-Fi
#
#                                             Synopsis Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...   TV     26.0
#
#                          Aired  ...  Studios    Source       Duration  \
# 0  Apr 3, 1998 to Apr 24, 1999  ...  Sunrise  Original  24 min per ep
#
#                            Rating  Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)  41.0         43     78525  914193.0
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
#
# [1 rows x 24 columns]

# %% [markdown]
# # Feature Selection

# %%
df.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='str')

# %%
df=df[["Name", "Synopsis", "Genres", "Studios", "Source", "Image URL"]]

# %%
df.head()
# Out:
#                               Name  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                             Synopsis  \
# 0  Crime is timeless. By the year 2071, humanity ...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Robin Sena is a powerful craft user drafted in...
# 4  It is the dark century and the people are suff...
#
#                                  Genres         Studios    Source  \
# 0         Action, Award Winning, Sci-Fi         Sunrise  Original
# 1                        Action, Sci-Fi           Bones  Original
# 2             Action, Adventure, Sci-Fi        Madhouse     Manga
# 3  Action, Drama, Mystery, Supernatural         Sunrise  Original
# 4      Adventure, Fantasy, Supernatural  Toei Animation     Manga
#
#                                            Image URL
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...

# %%
df.shape
# Out:
# (24905, 6)

# %% [markdown]
# # Dataset preprocessing

# %% [markdown]
# ## 'Genre' feature

# %%
def genre_convert(text):
    text= text.lower().replace("unknown"," ")
    genre= text.replace("-"," ").split(",")
    return [g.strip() for g in genre if g.strip()]

# %%
df["Genres"]=df["Genres"].apply(genre_convert)

# %%
df.head()
# Out:
#                               Name  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                             Synopsis  \
# 0  Crime is timeless. By the year 2071, humanity ...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Robin Sena is a powerful craft user drafted in...
# 4  It is the dark century and the people are suff...
#
#                                    Genres         Studios    Source  \
# 0         [action, award winning, sci fi]         Sunrise  Original
# 1                        [action, sci fi]           Bones  Original
# 2             [action, adventure, sci fi]        Madhouse     Manga
# 3  [action, drama, mystery, supernatural]         Sunrise  Original
# 4      [adventure, fantasy, supernatural]  Toei Animation     Manga
#
#                                            Image URL
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...

# %%
df["Genres"]=df["Genres"].apply(lambda x: [i.replace(" ","") for i in x])

# %%
df.head()
# Out:
#                               Name  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                             Synopsis  \
# 0  Crime is timeless. By the year 2071, humanity ...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Robin Sena is a powerful craft user drafted in...
# 4  It is the dark century and the people are suff...
#
#                                    Genres         Studios    Source  \
# 0           [action, awardwinning, scifi]         Sunrise  Original
# 1                         [action, scifi]           Bones  Original
# 2              [action, adventure, scifi]        Madhouse     Manga
# 3  [action, drama, mystery, supernatural]         Sunrise  Original
# 4      [adventure, fantasy, supernatural]  Toei Animation     Manga
#
#                                            Image URL
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...

# %% [markdown]
# ## 'Source' feature

# %%
def source_convert(text):
    source= text.lower().replace("-"," ").replace(" ","")
    return [source]

# %%
df["Source"]=df["Source"].apply(source_convert)

# %%
df.head()
# Out:
#                               Name  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                             Synopsis  \
# 0  Crime is timeless. By the year 2071, humanity ...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Robin Sena is a powerful craft user drafted in...
# 4  It is the dark century and the people are suff...
#
#                                    Genres         Studios      Source  \
# 0           [action, awardwinning, scifi]         Sunrise  [original]
# 1                         [action, scifi]           Bones  [original]
# 2              [action, adventure, scifi]        Madhouse     [manga]
# 3  [action, drama, mystery, supernatural]         Sunrise  [original]
# 4      [adventure, fantasy, supernatural]  Toei Animation     [manga]
#
#                                            Image URL
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...

# %% [markdown]
# ## 'Studios' feature

# %%
def studios_convert(text):
    text= text.lower().replace("unknown"," ")
    studio= text.replace("-"," ").replace(" ","").replace(".","").split(",")
    return [s.strip() for s in studio if s.strip()]

# %%
df["Studios"]=df["Studios"].apply(studios_convert)

# %%
df.head()
# Out:
#                               Name  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                             Synopsis  \
# 0  Crime is timeless. By the year 2071, humanity ...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Robin Sena is a powerful craft user drafted in...
# 4  It is the dark century and the people are suff...
#
#                                    Genres          Studios      Source  \
# 0           [action, awardwinning, scifi]        [sunrise]  [original]
# 1                         [action, scifi]          [bones]  [original]
# 2              [action, adventure, scifi]       [madhouse]     [manga]
# 3  [action, drama, mystery, supernatural]        [sunrise]  [original]
# 4      [adventure, fantasy, supernatural]  [toeianimation]     [manga]
#
#                                            Image URL
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...

# %% [markdown]
# ## 'Synopsis' feature

# %%
df["Synopsis"]=df["Synopsis"].apply(lambda x:x.split())

# %%
df.head()
# Out:
#                               Name  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                             Synopsis  \
# 0  [Crime, is, timeless., By, the, year, 2071,, h...
# 1  [Another, day,, another, bounty—such, is, the,...
# 2  [Vash, the, Stampede, is, the, man, with, a, $...
# 3  [Robin, Sena, is, a, powerful, craft, user, dr...
# 4  [It, is, the, dark, century, and, the, people,...
#
#                                    Genres          Studios      Source  \
# 0           [action, awardwinning, scifi]        [sunrise]  [original]
# 1                         [action, scifi]          [bones]  [original]
# 2              [action, adventure, scifi]       [madhouse]     [manga]
# 3  [action, drama, mystery, supernatural]        [sunrise]  [original]
# 4      [adventure, fantasy, supernatural]  [toeianimation]     [manga]
#
#                                            Image URL
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...

# %% [markdown]
# # New Feature: Tags

# %%
df["Tags"]=df["Synopsis"]+df["Genres"]+df["Studios"]+df["Source"]
df["Tags"] = df["Tags"].apply(lambda x: " ".join(x))

# %%
df.head()
# Out:
#                               Name  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                             Synopsis  \
# 0  [Crime, is, timeless., By, the, year, 2071,, h...
# 1  [Another, day,, another, bounty—such, is, the,...
# 2  [Vash, the, Stampede, is, the, man, with, a, $...
# 3  [Robin, Sena, is, a, powerful, craft, user, dr...
# 4  [It, is, the, dark, century, and, the, people,...
#
#                                    Genres          Studios      Source  \
# 0           [action, awardwinning, scifi]        [sunrise]  [original]
# 1                         [action, scifi]          [bones]  [original]
# 2              [action, adventure, scifi]       [madhouse]     [manga]
# 3  [action, drama, mystery, supernatural]        [sunrise]  [original]
# 4      [adventure, fantasy, supernatural]  [toeianimation]     [manga]
#
#                                            Image URL  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
#                                                 Tags
# 0  Crime is timeless. By the year 2071, humanity ...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Robin Sena is a powerful craft user drafted in...
# 4  It is the dark century and the people are suff...

# %% [markdown]
# # Final Dataset

# %%
new_df=df[["Name","Image URL","Tags"]]

# %%
new_df.head()
# Out:
#                               Name  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                            Image URL  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
#                                                 Tags
# 0  Crime is timeless. By the year 2071, humanity ...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Robin Sena is a powerful craft user drafted in...
# 4  It is the dark century and the people are suff...

# %%
new_df.to_csv("../data/processed/anime_processed.csv",index=False)
